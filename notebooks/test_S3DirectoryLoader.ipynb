# %%
from langchain.document_loaders import S3DirectoryLoader

# %%
import os
import s3fs

# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={"endpoint_url": S3_ENDPOINT_URL})

# %%
URL = "s3://projet-llm-insee-open-data/data/test"

with fs.open(URL, "r") as f:
    loader = S3DirectoryLoader(f.name)
    documents = loader.load()

# %%
import pandas as pd

BUCKET = "projet-llm-insee-open-data"
FILE_KEY_S3 = "data/test.csv"
FILE_PATH_S3 = BUCKET + "/" + FILE_KEY_S3

with fs.open(FILE_PATH_S3, mode="rb") as file_in:
    df = pd.read_csv(file_in, sep=";")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[5], line 6
#       3 FILE_KEY_S3 = "data/test.csv"
#       4 FILE_PATH_S3 = BUCKET + "/" + FILE_KEY_S3
# ----> 6 with fs.open(FILE_PATH_S3, mode="rb") as file_in:
#       7     df = pd.read_csv(file_in, sep=";")
#
# File /opt/mamba/lib/python3.11/site-packages/fsspec/spec.py:1293, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1291 else:
#    1292     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1293     f = self._open(
#    1294         path,
#    1295         mode=mode,
#    1296         block_size=block_size,
#    1297         autocommit=ac,
#    1298         cache_options=cache_options,
#    1299         **kwargs,
#    1300     )
#    1301     if compression is not None:
#    1302         from fsspec.compression import compr
#
# File /opt/mamba/lib/python3.11/site-packages/s3fs/core.py:685, in S3FileSystem._open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, size, requester_pays, cache_options, **kwargs)
#     682 if cache_type is None:
#     683     cache_type = self.default_cache_type
# --> 685 return S3File(
#     686     self,
#     687     path,
#     688     mode,
#     689     block_size=block_size,
#     690     acl=acl,
#     691     version_id=version_id,
#     692     fill_cache=fill_cache,
#     693     s3_additional_kwargs=kw,
#     694     cache_type=cache_type,
#     695     autocommit=autocommit,
#     696     requester_pays=requester_pays,
#     697     cache_options=cache_options,
#     698     size=size,
#     699 )
#
# File /opt/mamba/lib/python3.11/site-packages/s3fs/core.py:2179, in S3File.__init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays, cache_options, size)
#    2177         self.details = s3.info(path)
#    2178         self.version_id = self.details.get("VersionId")
# -> 2179 super().__init__(
#    2180     s3,
#    2181     path,
#    2182     mode,
#    2183     block_size,
#    2184     autocommit=autocommit,
#    2185     cache_type=cache_type,
#    2186     cache_options=cache_options,
#    2187     size=size,
#    2188 )
#    2189 self.s3 = self.fs  # compatibility
#    2191 # when not using autocommit we want to have transactional state to manage
#
# File /opt/mamba/lib/python3.11/site-packages/fsspec/spec.py:1651, in AbstractBufferedFile.__init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1649         self.size = size
#    1650     else:
# -> 1651         self.size = self.details["size"]
#    1652     self.cache = caches[cache_type](
#    1653         self.blocksize, self._fetch_range, self.size, **cache_options
#    1654     )
#    1655 else:
#
# File /opt/mamba/lib/python3.11/site-packages/fsspec/spec.py:1664, in AbstractBufferedFile.details(self)
#    1661 @property
#    1662 def details(self):
#    1663     if self._details is None:
# -> 1664         self._details = self.fs.info(self.path)
#    1665     return self._details
#
# File /opt/mamba/lib/python3.11/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /opt/mamba/lib/python3.11/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File /opt/mamba/lib/python3.11/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File /opt/mamba/lib/python3.11/site-packages/s3fs/core.py:1371, in S3FileSystem._info(self, path, bucket, key, refresh, version_id)
#    1369 if key:
#    1370     try:
# -> 1371         out = await self._call_s3(
#    1372             "head_object",
#    1373             self.kwargs,
#    1374             Bucket=bucket,
#    1375             Key=key,
#    1376             **version_id_kw(version_id),
#    1377             **self.req_kw,
#    1378         )
#    1379         return {
#    1380             "ETag": out.get("ETag", ""),
#    1381             "LastModified": out.get("LastModified", ""),
#    (...)
#    1387             "ContentType": out.get("ContentType"),
#    1388         }
#    1389     except FileNotFoundError:
#
# File /opt/mamba/lib/python3.11/site-packages/s3fs/core.py:362, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     360 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     361 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 362 return await _error_wrapper(
#     363     method, kwargs=additional_kwargs, retries=self.retries
#     364 )
#
# File /opt/mamba/lib/python3.11/site-packages/s3fs/core.py:142, in _error_wrapper(func, args, kwargs, retries)
#     140         err = e
#     141 err = translate_boto_error(err)
# --> 142 raise err
#
# File /opt/mamba/lib/python3.11/site-packages/s3fs/core.py:113, in _error_wrapper(func, args, kwargs, retries)
#     111 for i in range(retries):
#     112     try:
# --> 113         return await func(*args, **kwargs)
#     114     except S3_RETRYABLE_ERRORS as e:
#     115         err = e
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/client.py:388, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     384     maybe_compress_request(
#     385         self.meta.config, request_dict, operation_model
#     386     )
#     387     apply_request_checksum(request_dict)
# --> 388     http, parsed_response = await self._make_request(
#     389         operation_model, request_dict, request_context
#     390     )
#     392 await self.meta.events.emit(
#     393     'after-call.{service_id}.{operation_name}'.format(
#     394         service_id=service_id, operation_name=operation_name
#    (...)
#     399     context=request_context,
#     400 )
#     402 if http.status_code >= 300:
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/client.py:416, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     412 async def _make_request(
#     413     self, operation_model, request_dict, request_context
#     414 ):
#     415     try:
# --> 416         return await self._endpoint.make_request(
#     417             operation_model, request_dict
#     418         )
#     419     except Exception as e:
#     420         await self.meta.events.emit(
#     421             'after-call-error.{service_id}.{operation_name}'.format(
#     422                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     426             context=request_context,
#     427         )
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/endpoint.py:98, in AioEndpoint._send_request(self, request_dict, operation_model)
#      96 context = request_dict['context']
#      97 self._update_retries_context(context, attempts)
# ---> 98 request = await self.create_request(request_dict, operation_model)
#      99 success_response, exception = await self._get_response(
#     100     request, operation_model, context
#     101 )
#     102 while await self._needs_retry(
#     103     attempts,
#     104     operation_model,
#    (...)
#     107     exception,
#     108 ):
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/endpoint.py:86, in AioEndpoint.create_request(self, params, operation_model)
#      82     service_id = operation_model.service_model.service_id.hyphenize()
#      83     event_name = 'request-created.{service_id}.{op_name}'.format(
#      84         service_id=service_id, op_name=operation_model.name
#      85     )
# ---> 86     await self._event_emitter.emit(
#      87         event_name,
#      88         request=request,
#      89         operation_name=operation_model.name,
#      90     )
#      91 prepared_request = self.prepare_request(request)
#      92 return prepared_request
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/hooks.py:66, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      63 logger.debug('Event %s: calling handler %s', event_name, handler)
#      65 # Await the handler if its a coroutine.
# ---> 66 response = await resolve_awaitable(handler(**kwargs))
#      67 responses.append((handler, response))
#      68 if stop_on_response and response is not None:
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/_helpers.py:15, in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      17     return obj
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/signers.py:24, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      19 async def handler(self, operation_name=None, request=None, **kwargs):
#      20     # This is typically hooked up to the "request-created" event
#      21     # from a client's event emitter.  When a new request is created
#      22     # this method is invoked to sign the request.
#      23     # Don't call this method directly.
# ---> 24     return await self.sign(operation_name, request)
#
# File /opt/mamba/lib/python3.11/site-packages/aiobotocore/signers.py:88, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      85     else:
#      86         raise e
# ---> 88 auth.add_auth(request)
#
# File /opt/mamba/lib/python3.11/site-packages/botocore/auth.py:418, in SigV4Auth.add_auth(self, request)
#     416 def add_auth(self, request):
#     417     if self.credentials is None:
# --> 418         raise NoCredentialsError()
#     419     datetime_now = datetime.datetime.utcnow()
#     420     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
Si je lance un service lié à projet-llm-insee-open-data 
je peux voir le H100 mais fs.open(FILE_PATH_S3,...) provoque une erreur :
NoCredentialsError: Unable to locate credentials
